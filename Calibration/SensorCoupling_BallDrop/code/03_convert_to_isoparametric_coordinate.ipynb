# %% [markdown]
# # Convert to isoparametric coordinate
# 2021.04.23 Kurama Okubo
#
# 2022.11.08 update for new balldrop test; update distance on isoparametric coordinate with the height of AE sensor.

# %% [markdown]
# The event location $(\xi, \eta)$ and station $(x_s, y_s= \pm W/2)$ on the global coordinate is converted on the sensor-local coordinate $\boldsymbol{\xi}'$ as:
#
# $$
#  \boldsymbol{\xi}' = \begin{cases}
#    [ -x_s +\xi, \eta - \dfrac{W}{2}], ~~ y_s \geq 0 \\
#    [ x_s - \xi, -(\eta + \dfrac{W}{2})], ~~ y_s < 0
#   \end{cases}
# $$
#
# <img src="schematics/Isoparametric_coordinate_noedge_AEevent.png" alt="isoparacoord" width="400"/>

# %% [markdown]
# ## Parameters

# %%
import os
import obspy
from obspy import read, Stream, Trace
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
from glob import glob
import numpy as np
import pandas as pd
import datetime
from datetime import timedelta
from tqdm import tqdm
import warnings

from matplotlib.patches import Rectangle, Circle, Ellipse

os.environ['TZ'] = 'GMT' # change time zone to avoid confusion in unix_tvec conversion

plt.rcParams["font.family"] = 'Arial'
# plt.rcParams["font.sans-serif"] = "DejaVu Sans, Arial, Helvetica, Lucida Grande, Verdana, Geneva, Lucid, Avant Garde, sans-serif"
plt.rcParams["font.size"] = 12
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 4.75
plt.rcParams["xtick.major.width"] = 0.75
plt.rcParams["xtick.minor.size"] = 3
plt.rcParams["xtick.minor.width"] = 0.4
plt.rcParams["xtick.minor.visible"] = True

plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.major.size"] = 4.75
plt.rcParams["ytick.major.width"] = 0.75
plt.rcParams["ytick.minor.size"] = 3
plt.rcParams["ytick.minor.width"] = 0.4
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["savefig.transparent"] = False
plt.rcParams['axes.linewidth'] = 0.75

# %%
figdir = "../figure/debug_p03_isocoord"
if not os.path.exists(figdir):
    os.makedirs(figdir)

# %%
# Path for event location table
eventloc_table = "../data/balldrop_locations.csv"

# Directory for picked waveforms
datadir = "../data/DATA_computeCF"

# Data outputdir
outdir = "../data/DATA_isocoord"

# channel table
channel_finame = '../../../Others/AEchanneltable/AEsensorlocation_onFB03_table.csv'

# %%
if not os.path.exists(outdir):
    os.makedirs(outdir)

# %%
df_eventloc = pd.read_csv(eventloc_table, index_col=0)

# %% [markdown]
# ## Read channel array

# %%
df_array = pd.read_csv(channel_finame)

channel_loc={}

for i in range(len(df_array)):
    stnm = df_array.iloc[i].Instrument_Label
    xtemp = df_array.iloc[i].North.astype('float')
    ytemp = df_array.iloc[i].East.astype('float')
    ztemp = df_array.iloc[i].Down.astype('float')
    channel_loc[stnm] = [xtemp, ytemp, ztemp]
    
channel_loc
# Out:
# {'OL01': [190.0, 50.0, 70.0],
#  'OL02': [410.0, 50.0, 70.0],
#  'OL03': [640.0, 50.0, 70.0],
#  'OL04': [910.0, 50.0, 70.0],
#  'OL05': [1160.0, 50.0, 70.0],
#  'OL06': [1370.0, 50.0, 70.0],
#  'OL07': [1660.0, 50.0, 70.0],
#  'OL08': [1910.0, 50.0, 70.0],
#  'OL09': [2160.0, 50.0, 70.0],
#  'OL10': [2410.0, 50.0, 70.0],
#  'OL11': [2650.0, 50.0, 70.0],
#  'OL12': [2910.0, 50.0, 70.0],
#  'OL13': [3160.0, 50.0, 70.0],
#  'OL14': [3410.0, 50.0, 70.0],
#  'OL15': [3660.0, 50.0, 70.0],
#  'OL16': [3910.0, 50.0, 70.0],
#  'OL17': [285.0, -50.0, 70.0],
#  'OL18': [535.0, -50.0, 70.0],
#  'OL19': [785.0, -50.0, 70.0],
#  'OL20': [1035.0, -50.0, 70.0],
#  'OL21': [1285.0, -50.0, 70.0],
#  'OL22': [1535.0, -50.0, 70.0],
#  'OL23': [1785.0, -50.0, 70.0],
#  'OL24': [2035.0, -50.0, 70.0],
#  'OL25': [2285.0, -50.0, 70.0],
#  'OL26': [2535.0, -50.0, 70.0],
#  'OL27': [2785.0, -50.0, 70.0],
#  'OL28': [3035.0, -50.0, 70.0],
#  'OL29': [3285.0, -50.0, 70.0],
#  'OL30': [3535.0, -50.0, 70.0],
#  'OL31': [3785.0, -50.0, 70.0],
#  'OL32': [4035.0, -50.0, 70.0]}

# %% [markdown]
# ## Search events close to AE sensor

# %%
df_iso_all = pd.DataFrame(columns=['OL', 'datacase', 'xs', 'ys', 'zs', 'xi', 'eta', 'zeta', 'dist', 'xi1', 'eta1', 'zeta1'])

AEsensors = list(channel_loc.keys())
max_dist = 400 # [mm]
W = 100; #[mm]

debug_count = 0
for stnm in AEsensors:
    df_iso = pd.DataFrame(columns=['OL', 'datacase', 'xs', 'ys', 'zs', 'xi', 'eta', 'zeta', 'dist', 'xi1', 'eta1', 'zeta1'])

    # stnm = AEsensors[8]
    station_loc = channel_loc[stnm]
    xs, ys, zs = station_loc
    eventind = []

    # find events within max_dist
    for index, row in df_eventloc.iterrows():
        source_loc = np.array([row['X'], row['Y'], row['Z']])*1e3 #[mm]
        dist = np.linalg.norm(source_loc-station_loc)
        debug_count += 1 # count number of all the pairs
        if dist <= max_dist:
            eventind.append(index)

    # Shift coordinates
    for eid in eventind:
        datacase, xi, eta, zeta, Er = df_eventloc.loc[eid].values
        if ys >= 0:
            # OL01-16
            xi1, eta1, zeta1 = [-xs/1e3 + xi, eta-W/2/1e3, 0] #[m]
            dist1 = np.linalg.norm([xi1, eta1, zeta1-(zs*1e-3)]) # correct the distance: 2022.11.08 

        elif ys < 0:
            # OL17-32
            xi1, eta1, zeta1 = [xs/1e3 - xi, -(eta + W/2/1e3), 0] #[m]
            dist1 = np.linalg.norm([xi1, eta1, zeta1-(zs*1e-3)])

        iso_tmp = pd.DataFrame([[stnm, datacase, xs/1e3, ys/1e3, zs/1e3, np.round(xi, 5), np.round(eta, 5), zeta, dist1, np.round(xi1, 5), np.round(eta1, 5), zeta1]],
                                           columns=['OL', 'datacase', 'xs', 'ys', 'zs', 'xi', 'eta', 'zeta', 'dist', 'xi1', 'eta1', 'zeta1'],
                                           index=["{}__{}".format(stnm, datacase)])
        if not df_iso.empty:
            df_iso = pd.concat([df_iso, iso_tmp])
        else:
            df_iso = iso_tmp

    # check location 
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))

    left = 0 #[mm]
    bottom = -50 #[mm]
    width = 4100 #[mm]
    height = 100 #[mm]
    aspect_ratio = 3 # aspect ratio of rectangular plot
    fontsize=12

    rect = Rectangle((left, bottom), width, height, fill=True, color='white')

    ax.add_patch(rect)

    # plot isoparametric source location
    for index, row in df_iso.iterrows():
        xi1   = row["xi1"]*1e3 #[mm]
        eta1  = row["eta1"]*1e3 #[mm]
        zeta1 = row["zeta1"]*1e3 #[mm]
        # plot best location
        ax.plot(xi1, eta1, marker='o', markersize=12, markerfacecolor="y", markeredgecolor='k', markeredgewidth=1)

    # plot location of stations
    df_st = df_iso[df_iso.OL == stnm]
    xs, ys = np.unique([df_st['xs'], df_st['ys']])
    ax.plot(0, -3, marker='v', markersize=12, color='c', mec='k')

    ax.set_xlim(-max_dist, max_dist)
    ax.set_ylim(-W, 0)
    ax.set_aspect(aspect_ratio)
#     ax.set_xlabel(r"$\xi$' [mm]", fontsize=fontsize)
#     ax.set_ylabel(r"$\eta$' [mm]", fontsize=fontsize)
    ax.set_xlabel(r"x' [mm]", fontsize=fontsize)
    ax.set_ylabel(r"y' [mm]", fontsize=fontsize)
    ax.invert_yaxis()
    
    if not os.path.exists(figdir+"/isoloc"):
        os.makedirs(figdir+"/isoloc")
        
    plt.savefig(figdir+"/isoloc/balldrop_isoloc_{}.png".format(stnm), format="png", dpi=150)
    
    if not df_iso_all.empty:
        df_iso_all = pd.concat([df_iso_all, df_iso])
    else:
        df_iso_all = df_iso

    plt.close()
    plt.clf()

# %%
print(debug_count)
# Out:
# 1024

# %%
df_iso_all.to_csv("../data/balldrop_events_isocoord.csv")
df_iso_all
# Out:
#                  OL datacase     xs    ys    zs     xi    eta  zeta      dist  \
# OL01__BD_0220  OL01  BD_0220  0.190  0.05  0.07  0.217 -0.006   0.0  0.093622
# OL01__BD_0340  OL01  BD_0340  0.190  0.05  0.07  0.339  0.001   0.0  0.171761
# OL01__BD_0460  OL01  BD_0460  0.190  0.05  0.07  0.458  0.001   0.0  0.281292
# OL01__BD_0580  OL01  BD_0580  0.190  0.05  0.07  0.578  0.004   0.0  0.396938
# OL02__BD_0220  OL02  BD_0220  0.410  0.05  0.07  0.217 -0.006   0.0  0.212803
# ...             ...      ...    ...   ...   ...    ...    ...   ...       ...
# OL31__BD_3820  OL31  BD_3820  3.785 -0.05  0.07  3.821  0.007   0.0  0.097185
# OL31__BD_3940  OL31  BD_3940  3.785 -0.05  0.07  3.941  0.001   0.0  0.178429
# OL32__BD_3700  OL32  BD_3700  4.035 -0.05  0.07  3.699  0.002   0.0  0.347131
# OL32__BD_3820  OL32  BD_3820  4.035 -0.05  0.07  3.821  0.007   0.0  0.232261
# OL32__BD_3940  OL32  BD_3940  4.035 -0.05  0.07  3.941  0.001   0.0  0.127816
#
#                  xi1   eta1  zeta1
# OL01__BD_0220  0.027 -0.056      0
# OL01__BD_0340  0.149 -0.049      0
# OL01__BD_0460  0.268 -0.049      0
# OL01__BD_0580  0.388 -0.046      0
# OL02__BD_0220 -0.193 -0.056      0
# ...              ...    ...    ...
# OL31__BD_3820 -0.036 -0.057      0
# OL31__BD_3940 -0.156 -0.051      0
# OL32__BD_3700  0.336 -0.052      0
# OL32__BD_3820  0.214 -0.057      0
# OL32__BD_3940  0.094 -0.051      0
#
# [193 rows x 12 columns]

# %% [markdown]
# ## Load waveform and save to pickle

# %%
pretrigger =  0.0 #[ms]
windowlen = 0.4 #[ms]

AEsensors = list(channel_loc.keys())

# stnm = AEsensors[10]
for stnm in AEsensors:
    print("Start processing {}".format(stnm))

    # select events associated with single station
    df_iso_st = df_iso_all[df_iso_all.OL==stnm]

    # dataind = df_iso_st.index[1]
    for dataind in df_iso_st.index:

        foname = outdir+"/obs_isocoord_{}.pickle".format(dataind)

        if os.path.exists(foname):
            print("{} exist: skipping.".format(foname.split('/')[-1]))
#             continue
            
        print(dataind)
        dist = df_iso_all[df_iso_all.index == dataind]["dist"].values[0]*1e3
        xi1   = df_iso_all[df_iso_all.index == dataind]["xi1"].values[0]
        eta1  = df_iso_all[df_iso_all.index == dataind]["eta1"].values[0]
        zeta1 = df_iso_all[df_iso_all.index == dataind]["zeta1"].values[0]

        OL, datacase = dataind.split('__')

        # read data
        finame = datadir+"/{}.pickle".format(datacase)
        st = read(finame)

        st_OL = st.select(station="{}".format(OL))
        if st_OL.count() != 1:
            warn("multiple traces found on single station-event combination.")

        # select trace
        tr = st_OL[0].copy()

        tr.stats.origintime = st.origintime
        tr.stats.tpick = st.tpick[OL] - tr.stats.origintime 

        tr.stats.pretrigger = pretrigger #[ms]
        tr.stats.windowlen = windowlen #[ms]

        st0 = tr.stats.starttime
        pt = timedelta(milliseconds = tr.stats.pretrigger)
        wt = timedelta(milliseconds = tr.stats.windowlen)
        ot = timedelta(milliseconds = tr.stats.origintime)


        starttime = st0+ot-pt
        endtime = st0+ot+wt

        tr_trim = tr.copy() # avoid error in multiple trim
        tr_trim.trim(starttime, endtime, pad=True, fill_value=0.0)

        tr_trim.stats.starttime = st0

        # store stats
        tr_trim.stats.dist = dist
        tr_trim.stats.xi1 = xi1
        tr_trim.stats.eta1 = eta1
        tr_trim.stats.zeta1 = zeta1

        tr_trim.write(foname, format="pickle")

        # plot check ot and pick time
        tvec = np.array(range(0, tr_trim.stats.npts))*tr_trim.stats.delta*1e3 - tr_trim.stats.pretrigger #[ms]
        tvec
        xlimit = [-1.5, 20.5]
        ylimit = [-1.0, 1.0]
        fig, ax = plt.subplots(1, 1, figsize=(8, 3))
        ax.plot(tvec, tr_trim.data, 'k-')
        ax.axvline(tr_trim.stats.tpick, c = 'b', ls = '--')
#         ax.set_xlim(xlimit)
#         ax.set_ylim(ylimit)

        ax.set_xlabel("Time [ms]", fontsize=fontsize)
        ax.set_ylabel("Amplitude [V]", fontsize=fontsize)
        ax.set_title("{} Dist={:.2f} mm".format(dataind, dist), fontsize=fontsize)

        if not os.path.exists(figdir+"/trim_isocoord_waveform"):
            os.makedirs(figdir+"/trim_isocoord_waveform")

        plt.savefig(figdir+"/trim_isocoord_waveform/trim_isocoord_{}.png".format(dataind), format="png", dpi=150)

        plt.clf()
        plt.close()
# Out:
# Start processing OL01
# obs_isocoord_OL01__BD_0220.pickle exist: skipping.
# OL01__BD_0220
# obs_isocoord_OL01__BD_0340.pickle exist: skipping.
# OL01__BD_0340
# obs_isocoord_OL01__BD_0460.pickle exist: skipping.
# OL01__BD_0460
# obs_isocoord_OL01__BD_0580.pickle exist: skipping.
# OL01__BD_0580
# Start processing OL02
# obs_isocoord_OL02__BD_0220.pickle exist: skipping.
# OL02__BD_0220
# obs_isocoord_OL02__BD_0340.pickle exist: skipping.
# OL02__BD_0340
# obs_isocoord_OL02__BD_0460.pickle exist: skipping.
# OL02__BD_0460
# obs_isocoord_OL02__BD_0580.pickle exist: skipping.
# OL02__BD_0580
# obs_isocoord_OL02__BD_0700.pickle exist: skipping.
# OL02__BD_0700
# Start processing OL03
# obs_isocoord_OL03__BD_0340.pickle exist: skipping.
# OL03__BD_0340
# obs_isocoord_OL03__BD_0460.pickle exist: skipping.
# OL03__BD_0460
# obs_isocoord_OL03__BD_0580.pickle exist: skipping.
# OL03__BD_0580
# obs_isocoord_OL03__BD_0700.pickle exist: skipping.
# OL03__BD_0700
# obs_isocoord_OL03__BD_0820.pickle exist: skipping.
# OL03__BD_0820
# obs_isocoord_OL03__BD_0940.pickle exist: skipping.
# OL03__BD_0940
# Start processing OL04
# obs_isocoord_OL04__BD_0580.pickle exist: skipping.
# OL04__BD_0580
# obs_isocoord_OL04__BD_0700.pickle exist: skipping.
# OL04__BD_0700
# obs_isocoord_OL04__BD_0820.pickle exist: skipping.
# OL04__BD_0820
# obs_isocoord_OL04__BD_0940.pickle exist: skipping.
# OL04__BD_0940
# obs_isocoord_OL04__BD_1060.pickle exist: skipping.
# OL04__BD_1060
# obs_isocoord_OL04__BD_1180.pickle exist: skipping.
# OL04__BD_1180
# Start processing OL05
# obs_isocoord_OL05__BD_0820.pickle exist: skipping.
# OL05__BD_0820
# obs_isocoord_OL05__BD_0940.pickle exist: skipping.
# OL05__BD_0940
# obs_isocoord_OL05__BD_1060.pickle exist: skipping.
# OL05__BD_1060
# obs_isocoord_OL05__BD_1180.pickle exist: skipping.
# OL05__BD_1180
# obs_isocoord_OL05__BD_1300.pickle exist: skipping.
# OL05__BD_1300
# obs_isocoord_OL05__BD_1420.pickle exist: skipping.
# OL05__BD_1420
# obs_isocoord_OL05__BD_1540.pickle exist: skipping.
# OL05__BD_1540
# Start processing OL06
# obs_isocoord_OL06__BD_1060.pickle exist: skipping.
# OL06__BD_1060
# obs_isocoord_OL06__BD_1180.pickle exist: skipping.
# OL06__BD_1180
# obs_isocoord_OL06__BD_1300.pickle exist: skipping.
# OL06__BD_1300
# obs_isocoord_OL06__BD_1420.pickle exist: skipping.
# OL06__BD_1420
# obs_isocoord_OL06__BD_1540.pickle exist: skipping.
# OL06__BD_1540
# obs_isocoord_OL06__BD_1660.pickle exist: skipping.
# OL06__BD_1660
# Start processing OL07
# obs_isocoord_OL07__BD_1300.pickle exist: skipping.
# OL07__BD_1300
# obs_isocoord_OL07__BD_1420.pickle exist: skipping.
# OL07__BD_1420
# obs_isocoord_OL07__BD_1540.pickle exist: skipping.
# OL07__BD_1540
# obs_isocoord_OL07__BD_1660.pickle exist: skipping.
# OL07__BD_1660
# obs_isocoord_OL07__BD_1780.pickle exist: skipping.
# OL07__BD_1780
# obs_isocoord_OL07__BD_1900.pickle exist: skipping.
# OL07__BD_1900
# obs_isocoord_OL07__BD_2020.pickle exist: skipping.
# OL07__BD_2020
# Start processing OL08
# obs_isocoord_OL08__BD_1540.pickle exist: skipping.
# OL08__BD_1540
# obs_isocoord_OL08__BD_1660.pickle exist: skipping.
# OL08__BD_1660
# obs_isocoord_OL08__BD_1780.pickle exist: skipping.
# OL08__BD_1780
# obs_isocoord_OL08__BD_1900.pickle exist: skipping.
# OL08__BD_1900
# obs_isocoord_OL08__BD_2020.pickle exist: skipping.
# OL08__BD_2020
# obs_isocoord_OL08__BD_2140.pickle exist: skipping.
# OL08__BD_2140
# obs_isocoord_OL08__BD_2260.pickle exist: skipping.
# OL08__BD_2260
# Start processing OL09
# obs_isocoord_OL09__BD_1780.pickle exist: skipping.
# OL09__BD_1780
# obs_isocoord_OL09__BD_1900.pickle exist: skipping.
# OL09__BD_1900
# obs_isocoord_OL09__BD_2020.pickle exist: skipping.
# OL09__BD_2020
# obs_isocoord_OL09__BD_2140.pickle exist: skipping.
# OL09__BD_2140
# obs_isocoord_OL09__BD_2260.pickle exist: skipping.
# OL09__BD_2260
# obs_isocoord_OL09__BD_2380.pickle exist: skipping.
# OL09__BD_2380
# obs_isocoord_OL09__BD_2500.pickle exist: skipping.
# OL09__BD_2500
# Start processing OL10
# obs_isocoord_OL10__BD_2020.pickle exist: skipping.
# OL10__BD_2020
# obs_isocoord_OL10__BD_2140.pickle exist: skipping.
# OL10__BD_2140
# obs_isocoord_OL10__BD_2260.pickle exist: skipping.
# OL10__BD_2260
# obs_isocoord_OL10__BD_2380.pickle exist: skipping.
# OL10__BD_2380
# obs_isocoord_OL10__BD_2500.pickle exist: skipping.
# OL10__BD_2500
# obs_isocoord_OL10__BD_2620.pickle exist: skipping.
# OL10__BD_2620
# obs_isocoord_OL10__BD_2740.pickle exist: skipping.
# OL10__BD_2740
# Start processing OL11
# obs_isocoord_OL11__BD_2380.pickle exist: skipping.
# OL11__BD_2380
# obs_isocoord_OL11__BD_2500.pickle exist: skipping.
# OL11__BD_2500
# obs_isocoord_OL11__BD_2620.pickle exist: skipping.
# OL11__BD_2620
# obs_isocoord_OL11__BD_2740.pickle exist: skipping.
# OL11__BD_2740
# obs_isocoord_OL11__BD_2860.pickle exist: skipping.
# OL11__BD_2860
# obs_isocoord_OL11__BD_2980.pickle exist: skipping.
# OL11__BD_2980
# Start processing OL12
# obs_isocoord_OL12__BD_2620.pickle exist: skipping.
# OL12__BD_2620
# obs_isocoord_OL12__BD_2740.pickle exist: skipping.
# OL12__BD_2740
# obs_isocoord_OL12__BD_2860.pickle exist: skipping.
# OL12__BD_2860
# obs_isocoord_OL12__BD_2980.pickle exist: skipping.
# OL12__BD_2980
# obs_isocoord_OL12__BD_3100.pickle exist: skipping.
# OL12__BD_3100
# obs_isocoord_OL12__BD_3220.pickle exist: skipping.
# OL12__BD_3220
# Start processing OL13
# obs_isocoord_OL13__BD_2860.pickle exist: skipping.
# OL13__BD_2860
# obs_isocoord_OL13__BD_2980.pickle exist: skipping.
# OL13__BD_2980
# obs_isocoord_OL13__BD_3100.pickle exist: skipping.
# OL13__BD_3100
# obs_isocoord_OL13__BD_3220.pickle exist: skipping.
# OL13__BD_3220
# obs_isocoord_OL13__BD_3340.pickle exist: skipping.
# OL13__BD_3340
# obs_isocoord_OL13__BD_3460.pickle exist: skipping.
# OL13__BD_3460
# Start processing OL14
# obs_isocoord_OL14__BD_3100.pickle exist: skipping.
# OL14__BD_3100
# obs_isocoord_OL14__BD_3220.pickle exist: skipping.
# OL14__BD_3220
# obs_isocoord_OL14__BD_3340.pickle exist: skipping.
# OL14__BD_3340
# obs_isocoord_OL14__BD_3460.pickle exist: skipping.
# OL14__BD_3460
# obs_isocoord_OL14__BD_3580.pickle exist: skipping.
# OL14__BD_3580
# obs_isocoord_OL14__BD_3700.pickle exist: skipping.
# OL14__BD_3700
# Start processing OL15
# obs_isocoord_OL15__BD_3340.pickle exist: skipping.
# OL15__BD_3340
# obs_isocoord_OL15__BD_3460.pickle exist: skipping.
# OL15__BD_3460
# obs_isocoord_OL15__BD_3580.pickle exist: skipping.
# OL15__BD_3580
# obs_isocoord_OL15__BD_3700.pickle exist: skipping.
# OL15__BD_3700
# obs_isocoord_OL15__BD_3820.pickle exist: skipping.
# OL15__BD_3820
# obs_isocoord_OL15__BD_3940.pickle exist: skipping.
# OL15__BD_3940
# Start processing OL16
# obs_isocoord_OL16__BD_3580.pickle exist: skipping.
# OL16__BD_3580
# obs_isocoord_OL16__BD_3700.pickle exist: skipping.
# OL16__BD_3700
# obs_isocoord_OL16__BD_3820.pickle exist: skipping.
# OL16__BD_3820
# obs_isocoord_OL16__BD_3940.pickle exist: skipping.
# OL16__BD_3940
# Start processing OL17
# obs_isocoord_OL17__BD_0220.pickle exist: skipping.
# OL17__BD_0220
# obs_isocoord_OL17__BD_0340.pickle exist: skipping.
# OL17__BD_0340
# obs_isocoord_OL17__BD_0460.pickle exist: skipping.
# OL17__BD_0460
# obs_isocoord_OL17__BD_0580.pickle exist: skipping.
# OL17__BD_0580
# Start processing OL18
# obs_isocoord_OL18__BD_0220.pickle exist: skipping.
# OL18__BD_0220
# obs_isocoord_OL18__BD_0340.pickle exist: skipping.
# OL18__BD_0340
# obs_isocoord_OL18__BD_0460.pickle exist: skipping.
# OL18__BD_0460
# obs_isocoord_OL18__BD_0580.pickle exist: skipping.
# OL18__BD_0580
# obs_isocoord_OL18__BD_0700.pickle exist: skipping.
# OL18__BD_0700
# obs_isocoord_OL18__BD_0820.pickle exist: skipping.
# OL18__BD_0820
# Start processing OL19
# obs_isocoord_OL19__BD_0460.pickle exist: skipping.
# OL19__BD_0460
# obs_isocoord_OL19__BD_0580.pickle exist: skipping.
# OL19__BD_0580
# obs_isocoord_OL19__BD_0700.pickle exist: skipping.
# OL19__BD_0700
# obs_isocoord_OL19__BD_0820.pickle exist: skipping.
# OL19__BD_0820
# obs_isocoord_OL19__BD_0940.pickle exist: skipping.
# OL19__BD_0940
# obs_isocoord_OL19__BD_1060.pickle exist: skipping.
# OL19__BD_1060
# obs_isocoord_OL19__BD_1180.pickle exist: skipping.
# OL19__BD_1180
# Start processing OL20
# obs_isocoord_OL20__BD_0700.pickle exist: skipping.
# OL20__BD_0700
# obs_isocoord_OL20__BD_0820.pickle exist: skipping.
# OL20__BD_0820
# obs_isocoord_OL20__BD_0940.pickle exist: skipping.
# OL20__BD_0940
# obs_isocoord_OL20__BD_1060.pickle exist: skipping.
# OL20__BD_1060
# obs_isocoord_OL20__BD_1180.pickle exist: skipping.
# OL20__BD_1180
# obs_isocoord_OL20__BD_1300.pickle exist: skipping.
# OL20__BD_1300
# obs_isocoord_OL20__BD_1420.pickle exist: skipping.
# OL20__BD_1420
# Start processing OL21
# obs_isocoord_OL21__BD_0940.pickle exist: skipping.
# OL21__BD_0940
# obs_isocoord_OL21__BD_1060.pickle exist: skipping.
# OL21__BD_1060
# obs_isocoord_OL21__BD_1180.pickle exist: skipping.
# OL21__BD_1180
# obs_isocoord_OL21__BD_1300.pickle exist: skipping.
# OL21__BD_1300
# obs_isocoord_OL21__BD_1420.pickle exist: skipping.
# OL21__BD_1420
# obs_isocoord_OL21__BD_1540.pickle exist: skipping.
# OL21__BD_1540
# obs_isocoord_OL21__BD_1660.pickle exist: skipping.
# OL21__BD_1660
# Start processing OL22
# obs_isocoord_OL22__BD_1180.pickle exist: skipping.
# OL22__BD_1180
# obs_isocoord_OL22__BD_1300.pickle exist: skipping.
# OL22__BD_1300
# obs_isocoord_OL22__BD_1420.pickle exist: skipping.
# OL22__BD_1420
# obs_isocoord_OL22__BD_1540.pickle exist: skipping.
# OL22__BD_1540
# obs_isocoord_OL22__BD_1660.pickle exist: skipping.
# OL22__BD_1660
# obs_isocoord_OL22__BD_1780.pickle exist: skipping.
# OL22__BD_1780
# obs_isocoord_OL22__BD_1900.pickle exist: skipping.
# OL22__BD_1900
# Start processing OL23
# obs_isocoord_OL23__BD_1420.pickle exist: skipping.
# OL23__BD_1420
# obs_isocoord_OL23__BD_1540.pickle exist: skipping.
# OL23__BD_1540
# obs_isocoord_OL23__BD_1660.pickle exist: skipping.
# OL23__BD_1660
# obs_isocoord_OL23__BD_1780.pickle exist: skipping.
# OL23__BD_1780
# obs_isocoord_OL23__BD_1900.pickle exist: skipping.
# OL23__BD_1900
# obs_isocoord_OL23__BD_2020.pickle exist: skipping.
# OL23__BD_2020
# obs_isocoord_OL23__BD_2140.pickle exist: skipping.
# OL23__BD_2140
# Start processing OL24
# obs_isocoord_OL24__BD_1660.pickle exist: skipping.
# OL24__BD_1660
# obs_isocoord_OL24__BD_1780.pickle exist: skipping.
# OL24__BD_1780
# obs_isocoord_OL24__BD_1900.pickle exist: skipping.
# OL24__BD_1900
# obs_isocoord_OL24__BD_2020.pickle exist: skipping.
# OL24__BD_2020
# obs_isocoord_OL24__BD_2140.pickle exist: skipping.
# OL24__BD_2140
# obs_isocoord_OL24__BD_2260.pickle exist: skipping.
# OL24__BD_2260
# obs_isocoord_OL24__BD_2380.pickle exist: skipping.
# OL24__BD_2380
# Start processing OL25
# obs_isocoord_OL25__BD_1900.pickle exist: skipping.
# OL25__BD_1900
# obs_isocoord_OL25__BD_2020.pickle exist: skipping.
# OL25__BD_2020
# obs_isocoord_OL25__BD_2140.pickle exist: skipping.
# OL25__BD_2140
# obs_isocoord_OL25__BD_2260.pickle exist: skipping.
# OL25__BD_2260
# obs_isocoord_OL25__BD_2380.pickle exist: skipping.
# OL25__BD_2380
# obs_isocoord_OL25__BD_2500.pickle exist: skipping.
# OL25__BD_2500
# obs_isocoord_OL25__BD_2620.pickle exist: skipping.
# OL25__BD_2620
# Start processing OL26
# obs_isocoord_OL26__BD_2260.pickle exist: skipping.
# OL26__BD_2260
# obs_isocoord_OL26__BD_2380.pickle exist: skipping.
# OL26__BD_2380
# obs_isocoord_OL26__BD_2500.pickle exist: skipping.
# OL26__BD_2500
# obs_isocoord_OL26__BD_2620.pickle exist: skipping.
# OL26__BD_2620
# obs_isocoord_OL26__BD_2740.pickle exist: skipping.
# OL26__BD_2740
# obs_isocoord_OL26__BD_2860.pickle exist: skipping.
# OL26__BD_2860
# Start processing OL27
# obs_isocoord_OL27__BD_2500.pickle exist: skipping.
# OL27__BD_2500
# obs_isocoord_OL27__BD_2620.pickle exist: skipping.
# OL27__BD_2620
# obs_isocoord_OL27__BD_2740.pickle exist: skipping.
# OL27__BD_2740
# obs_isocoord_OL27__BD_2860.pickle exist: skipping.
# OL27__BD_2860
# obs_isocoord_OL27__BD_2980.pickle exist: skipping.
# OL27__BD_2980
# obs_isocoord_OL27__BD_3100.pickle exist: skipping.
# OL27__BD_3100
# Start processing OL28
# obs_isocoord_OL28__BD_2740.pickle exist: skipping.
# OL28__BD_2740
# obs_isocoord_OL28__BD_2860.pickle exist: skipping.
# OL28__BD_2860
# obs_isocoord_OL28__BD_2980.pickle exist: skipping.
# OL28__BD_2980
# obs_isocoord_OL28__BD_3100.pickle exist: skipping.
# OL28__BD_3100
# obs_isocoord_OL28__BD_3220.pickle exist: skipping.
# OL28__BD_3220
# obs_isocoord_OL28__BD_3340.pickle exist: skipping.
# OL28__BD_3340
# Start processing OL29
# obs_isocoord_OL29__BD_2980.pickle exist: skipping.
# OL29__BD_2980
# obs_isocoord_OL29__BD_3100.pickle exist: skipping.
# OL29__BD_3100
# obs_isocoord_OL29__BD_3220.pickle exist: skipping.
# OL29__BD_3220
# obs_isocoord_OL29__BD_3340.pickle exist: skipping.
# OL29__BD_3340
# obs_isocoord_OL29__BD_3460.pickle exist: skipping.
# OL29__BD_3460
# obs_isocoord_OL29__BD_3580.pickle exist: skipping.
# OL29__BD_3580
# Start processing OL30
# obs_isocoord_OL30__BD_3220.pickle exist: skipping.
# OL30__BD_3220
# obs_isocoord_OL30__BD_3340.pickle exist: skipping.
# OL30__BD_3340
# obs_isocoord_OL30__BD_3460.pickle exist: skipping.
# OL30__BD_3460
# obs_isocoord_OL30__BD_3580.pickle exist: skipping.
# OL30__BD_3580
# obs_isocoord_OL30__BD_3700.pickle exist: skipping.
# OL30__BD_3700
# obs_isocoord_OL30__BD_3820.pickle exist: skipping.
# OL30__BD_3820
# Start processing OL31
# obs_isocoord_OL31__BD_3460.pickle exist: skipping.
# OL31__BD_3460
# obs_isocoord_OL31__BD_3580.pickle exist: skipping.
# OL31__BD_3580
# obs_isocoord_OL31__BD_3700.pickle exist: skipping.
# OL31__BD_3700
# obs_isocoord_OL31__BD_3820.pickle exist: skipping.
# OL31__BD_3820
# obs_isocoord_OL31__BD_3940.pickle exist: skipping.
# OL31__BD_3940
# Start processing OL32
# obs_isocoord_OL32__BD_3700.pickle exist: skipping.
# OL32__BD_3700
# obs_isocoord_OL32__BD_3820.pickle exist: skipping.
# OL32__BD_3820
# obs_isocoord_OL32__BD_3940.pickle exist: skipping.
# OL32__BD_3940

# %%
tr1 = read(outdir+"/obs_isocoord_OL10__BD_2740.pickle")[0]
tr1.stats
tr1.plot()

# %% [markdown]
# ## Plot events associated with single station

# %%
vmean = 6200

for stnm in AEsensors:
    df_iso_st = df_iso_all[df_iso_all.OL==stnm]
    xlimit = [0.0, 0.4]
    ylimit = [-1.2, 1.2]
    fig, axs = plt.subplots(len(df_iso_st), 1, figsize=(12, 12), sharex=True)

    for i, dataind in enumerate(df_iso_st.index):

        OL, datacase = dataind.split('__')
        # read trace
        tr_trim = read(outdir+"/obs_isocoord_{}.pickle".format(dataind))[0]

        tvec = np.array(range(0, tr_trim.stats.npts))*tr_trim.stats.delta*1e3 - tr_trim.stats.pretrigger #[ms]
        axs[i].plot(tvec, tr_trim.data*1e3, 'k-')
        axs[i].axvline(tr_trim.stats.tpick, c = 'b', ls = '--')
        # pick time from theoretical arrival
        axs[i].axvline(tr_trim.stats.dist/vmean, c = 'r', ls = '--')
        axs[i].set_xlim(xlimit)
        axs[i].set_ylim(ylimit)
        if i == len(df_iso_st)-1:
            axs[i].set_xlabel("Time [ms]", fontsize=fontsize)

        axs[i].set_ylabel("Velocity [mm/s]", fontsize=fontsize)
        axs[i].set_title("{} Dist={:.2f} mm".format(dataind, tr_trim.stats.dist), fontsize=fontsize)
        axs[i].tick_params(direction='in')

    fig.tight_layout()
    if not os.path.exists(figdir+"/events_on_single"):
        os.makedirs(figdir+"/events_on_single")

    plt.savefig(figdir+"/events_on_single/events_on_single_{}.png".format(stnm), format="png", dpi=150)

    plt.clf()
    plt.close()

# %% [markdown]
# ## Save green's function location file for OpenSWPC modeling

# %%
# df_iso_all = pd.read_csv("../data/balldrop_events_isocoord.csv",  index_col=[0])

# fo = open("../data/green_in_balldrop.txt", "w")
# fo.write("# balldrop event loc for green's function\n#     x     y    z    gid\n# --------------------------------------------------------------------------------------------\n")
# for index, row in df_iso_all.iterrows():
#     xi1, eta1, zeta1, gid = [row["xi1"], row["eta1"], row["zeta1"], index]
#     fo.write("{:.8e} {:.8e} {:.8e} {}\n".format(xi1/1e3, eta1/1e3, zeta1/1e3, gid)) # locations are in [km]
    
# fo.close()

# %%
# save green txt for side coordinate
df_iso_all = pd.read_csv("../data/balldrop_events_isocoord.csv",  index_col=[0])

dy = 1.0e-6

fo = open("../data/green_in_balldrop_sidecoord.txt", "w")
fo.write("# balldrop event loc for green's function\n#     x     y    z    gid\n# --------------------------------------------------------------------------------------------\n")
gindex = 0
gindex_dict = {}
for index, row in df_iso_all.iterrows():
    xi1, eta1, zeta1, gid = [row["xi1"], row["eta1"], row["zeta1"], index]
    fo.write("{:.8e} {:.8e} {:.8e} {}\n".format(xi1/1e3, zeta1/1e3+dy, -eta1/1e3, gindex)) # locations are in [km]
    gindex_dict[index] = gindex
    gindex = gindex+1
    
fo.close()

# %%
# save green function index table
df_gindex = pd.DataFrame(gindex_dict.items(), columns=['index', 'gid'])
df_gindex.to_csv("../data/gindex_table.csv")

# %% [markdown]
# NOTE: the arrival time is modified from the preliminary result due to the removal of instremental response.
